# %% [markdown]
# # Exercise 1
#
# ![image-2.png](attachment:image-2.png)

# %%
# the square of the matrix:
import numpy as np
a = np.matrix([[1, 2, 3],
               [4, 5, 6],
               [7, 8, 9]])
a * a
# Out:
# matrix([[ 30,  36,  42],
#         [ 66,  81,  96],
#         [102, 126, 150]])

# %%
# the determinant of the matrix
print(np.linalg.det(a))  # the actual determinant is 0 actually, sigh...
print(1*5*9 + 2*6*7 + 3*4*8 - 1*6*8 - 2*4*9 - 3*5*7)
# Out:
# -9.51619735392994e-16
# 0

# %%
# the transpose
np.matrix.transpose(a)
# Out:
# matrix([[1, 4, 7],
#         [2, 5, 8],
#         [3, 6, 9]])
